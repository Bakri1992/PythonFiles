# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/160.8 kB ? eta -:--:--
#      --------- --------------------------- 41.0/160.8 kB 653.6 kB/s eta 0:00:01
#      ------------------------------------ - 153.6/160.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 160.8/160.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.6 MB 4.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/7.6 MB 6.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.6 MB 9.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.6 MB 10.9 MB/s eta 0:00:01
#    -------------- ------------------------- 2.8/7.6 MB 13.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.3/7.6 MB 11.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ergebnisse nach erstem Durchlauf für Set und Liste
# mit Filterung der Wortliste nach max. 7 Buchstaben
res = pd.DataFrame({"List":[0.08,178.8,809.92,3570.05,16300.54,None,None],"Set":[4772.85,469.4,470.33,538.26,394.9,608.33,1151.08]})

# %%
plt.plot(range(1,8),res.Set, color="darkblue", label="set")
plt.plot(range(1,8),res.List, color="darkred", label="list")
plt.ylabel("seconds")
plt.xlabel("length of input")
plt.legend()
plt.show()

# %%
res_binary = res.copy()
res_binary["list_binary"] = [0.04,2.04,10.21,37.13,185.94,1396.12,8102.49]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 res_binary = res.copy()
#       2 res_binary["list_binary"] = [0.04,2.04,10.21,37.13,185.94,1396.12,8102.49]
#
# NameError: name 'res' is not defined

# %%
plt.plot(range(1,8),res_binary.Set, color="darkblue", label="set")
plt.plot(range(1,8),res_binary.List, color="darkred", label="list")
plt.plot(range(1,8),res_binary.list_binary, color="red", label="list_binary")
plt.ylabel("seconds")
plt.xlabel("length of input")
plt.legend()
plt.show()

# %%
res_binary2 = res_binary.copy()
res_binary2["list_binary2"] = [0.04,2.46,13.13,58.72,294.04,1367.49,6978.97]

# %%
plt.plot(range(1,8),res_binary2.Set, color="darkblue", label="set")
plt.plot(range(1,8),res_binary2.List, color="darkred", label="list")
plt.plot(range(1,8),res_binary2.list_binary, color="red", label="list_binary")
plt.plot(range(1,8),res_binary2.list_binary2, color="pink", label="list_binary ohne Filter")
plt.ylabel("seconds")
plt.xlabel("length of input")
plt.legend()
plt.show()

# %%
res_hash = res_binary2.copy()
res_hash["hash"] = [
    752.32,
    730.88,
    727.43,
    728.89,
    755.53,
    729.25,+
    971.76,
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 res_hash = res_binary2.copy()
#       2 res_hash["hash"] = [
#       3     752.32,
#       4     730.88,
#    (...)
#       9     971.76,
#      10 ]
#
# NameError: name 'res_binary2' is not defined

# %%
plt.plot(range(1,8),res_hash.Set, color="darkblue", label="set")
plt.plot(range(1,8),res_hash.List, color="darkred", label="list")
plt.plot(range(1,8),res_hash.list_binary, color="red", label="list_binary")
plt.plot(range(1,8),res_hash.list_binary2, color="pink", label="list_binary ohne Filter")
plt.plot(range(1,8),res_hash.hash, color="darkgreen", label="hash")
plt.ylabel("seconds")
plt.xlabel("length of input")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.plot(range(1,8),res_hash.Set, color="darkblue", label="set")
#       2 plt.plot(range(1,8),res_hash.List, color="darkred", label="list")
#       3 plt.plot(range(1,8),res_hash.list_binary, color="red", label="list_binary")
#
# NameError: name 'res_hash' is not defined
